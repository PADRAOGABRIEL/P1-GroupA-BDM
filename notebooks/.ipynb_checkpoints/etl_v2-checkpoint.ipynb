# %% [markdown]
# ## Imports used across ETL exploration and final incremental pipeline

# %%
import time
import os, json, shutil
from datetime import datetime, timezone
from pyspark.sql.functions import col, current_timestamp, input_file_name, to_date, unix_timestamp, broadcast, desc, when, lit, concat, floor, rand, regexp_replace, sum as Fsum, round as Fround
from pyspark.sql import SparkSession

# %% [markdown]
# ## Centralized project paths for input, output, lookup, and ETL state

# %%
BASE_PATH = "/home/jovyan/work"

INBOX = f"{BASE_PATH}/data/inbox"
OUTBOX = f"{BASE_PATH}/data/outbox/trips_enriched.parquet"
LOOKUP = f"{BASE_PATH}/data/taxi_zone_lookup.parquet"
STATE = f"{BASE_PATH}/state/manifest.json"

# %% [markdown]
# ## Read manifest file that tracks already processed input files

# %%
def load_manifest(path):
    if not os.path.exists(path):
        return {"processed_files": []}
    with open(path, "r") as f:
        return json.load(f)

# %% [markdown]
# ## Persist updated manifest to keep ingestion incremental and idempotent

# %%
def save_manifest(path, manifest):
    with open(path, "w") as f:
        json.dump(manifest, f, indent=2)

# %% [markdown]
# ## Compute full input list and the subset of files that are new in this run

# %%
manifest = load_manifest(STATE)
processed = set(x["filename"] for x in manifest["processed_files"])

all_files = sorted([f for f in os.listdir(INBOX) if f.endswith(".parquet")])
new_files = [f for f in all_files if f not in processed]

print("All files:", all_files)
print("New files:", new_files)
# Out:
# All files: ['yellow_tripdata_2025-01.parquet']
# New files: ['yellow_tripdata_2025-01.parquet']

# %% [markdown]
# ## Initialize Spark session for the ETL run

# %%
spark = SparkSession.builder.appName("Project1-ETL").getOrCreate()

# %% [markdown]
# ## Helper to verify whether output parquet folder already contains data files

# %%
def outbox_has_data(path: str) -> bool:
    return (
        os.path.exists(path)
        and os.path.isdir(path)
        and any(name.startswith("part-") and name.endswith(".parquet") for name in os.listdir(path))
    )

# %% [markdown]
# ## Bad Rows Helper

# %%
# Centralizes bad-row inspection so it can be called at any point,
# independently of whether the main ETL block ran in this session.

BAD_ROW_COLS = ["passenger_count", "trip_distance", "tpep_pickup_datetime", "tpep_dropoff_datetime", "fare_amount", "tip_amount", "total_amount", "tolls_amount"]

def display_bad_rows(df_typed, label: str, condition, limit: int = 5) -> None:
    """
    Print a labelled sample of rows that match *condition* on *df_typed*.

    Parameters
    ----------
    df_typed  : Spark DataFrame after type casting
    label     : Human-readable description printed as a header
    condition : Column expression used as the filter (e.g. col("trip_distance") <= 0)
    limit     : Max rows to display (default 5)
    """
    bad = df_typed.filter(condition)
    count = bad.count()
    print(f"\n{'='*55}")
    print(f"  BAD ROWS — {label}")
    print(f"  Total: {count:,} rows")
    print(f"{'='*55}")
    if count == 0:
        print("  ✓ No bad rows found.")
    else:
        bad.select(BAD_ROW_COLS).limit(limit).show(truncate=False)


def get_typed_df(spark, inbox_path: str):
    """
    Read ALL parquet files from *inbox_path* and return a typed DataFrame.
    Useful when you want to inspect bad rows without running the full ETL.
    """
    
    all_files = sorted([f for f in os.listdir(inbox_path) if f.endswith(".parquet")])
    if not all_files:
        raise FileNotFoundError(f"No parquet files found in {inbox_path}")

    paths = [os.path.join(inbox_path, f) for f in all_files]
    df = spark.read.parquet(*paths).withColumn("source_file", input_file_name())

    return (
        df
        .withColumn("tpep_pickup_datetime",  col("tpep_pickup_datetime").cast("timestamp"))
        .withColumn("tpep_dropoff_datetime", col("tpep_dropoff_datetime").cast("timestamp"))
        .withColumn("passenger_count",       col("passenger_count").cast("int"))
        .withColumn("trip_distance",         col("trip_distance").cast("double"))
        .withColumn("PULocationID",          col("PULocationID").cast("int"))
        .withColumn("DOLocationID",          col("DOLocationID").cast("int"))
        .withColumn("VendorID",              col("VendorID").cast("int"))
    )

# %% [markdown]
# ## Bad Rows Examples

# %%
df_typed = get_typed_df(spark, INBOX)

display_bad_rows(df_typed, "Trip distance <= 0",      col("trip_distance") <= 0)
display_bad_rows(df_typed, "Dropoff before pickup",   col("tpep_dropoff_datetime") < col("tpep_pickup_datetime"))
display_bad_rows(df_typed, "Passenger count <= 0",    col("passenger_count") <= 0)
display_bad_rows(df_typed, "Fare amount < 0",         col("fare_amount") < 0)
display_bad_rows(df_typed, "Total amount < 0",        col("total_amount") < 0)
display_bad_rows(df_typed, "Tip amount < 0",          col("tip_amount") < 0)
display_bad_rows(df_typed, "Tolls amount < 0",        col("tolls_amount") < 0)
# Out:
# =======================================================
#   BAD ROWS — Trip distance <= 0
#   Total: 90,893 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |1              |0.0          |2025-01-01 00:49:48 |2025-01-01 00:49:48  |20.06      |0.0       |20.06       |0.0         |
# |1              |0.0          |2025-01-01 00:37:43 |2025-01-01 00:37:53  |12.0       |2.0       |17.5        |0.0         |
# |3              |0.0          |2025-01-01 00:57:08 |2025-01-01 00:57:16  |30.0       |0.0       |33.5        |0.0         |
# |1              |0.0          |2025-01-01 00:27:40 |2025-01-01 00:59:30  |50.5       |0.0       |58.94       |6.94        |
# |4              |0.0          |2025-01-01 00:56:49 |2025-01-01 00:56:54  |20.0       |7.05      |30.55       |0.0         |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
#
#
# =======================================================
#   BAD ROWS — Dropoff before pickup
#   Total: 124 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |1              |9.0          |2025-01-02 12:26:00 |2025-01-02 11:29:58  |45.5       |0.0       |46.0        |0.0         |
# |1              |3.8          |2025-01-06 16:00:00 |2025-01-06 15:05:30  |24.5       |0.0       |25.0        |0.0         |
# |1              |1.0          |2025-01-15 15:00:00 |2025-01-15 14:42:48  |18.5       |0.0       |19.0        |0.0         |
# |0              |3.1          |2025-01-23 01:44:59 |2024-12-18 07:52:40  |21.9       |4.5       |30.4        |0.0         |
# |1              |3.9          |2025-01-23 12:30:00 |2025-01-23 11:44:59  |27.5       |0.0       |28.0        |0.0         |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
#
#
# =======================================================
#   BAD ROWS — Passenger count <= 0
#   Total: 24,656 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |0              |0.4          |2025-01-01 00:14:47 |2025-01-01 00:16:15  |4.4        |2.35      |11.75       |0.0         |
# |0              |1.6          |2025-01-01 00:39:27 |2025-01-01 00:51:51  |12.1       |2.0       |19.1        |0.0         |
# |0              |2.8          |2025-01-01 00:53:43 |2025-01-01 01:13:23  |19.1       |3.0       |27.1        |0.0         |
# |0              |0.7          |2025-01-01 00:11:27 |2025-01-01 00:16:58  |7.2        |0.0       |12.2        |0.0         |
# |0              |1.0          |2025-01-01 00:19:30 |2025-01-01 00:27:25  |9.3        |2.85      |17.15       |0.0         |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
#
#
# =======================================================
#   BAD ROWS — Fare amount < 0
#   Total: 144,118 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |1              |0.71         |2025-01-01 00:01:41 |2025-01-01 00:07:14  |-7.2       |3.66      |-8.54       |0.0         |
# |1              |0.69         |2025-01-01 00:55:54 |2025-01-01 01:00:38  |-6.5       |0.0       |-11.5       |0.0         |
# |1              |0.97         |2025-01-01 00:56:12 |2025-01-01 01:15:00  |-16.3      |0.0       |-21.3       |0.0         |
# |1              |1.42         |2025-01-01 00:55:53 |2025-01-01 01:06:49  |-12.1      |0.0       |-17.1       |0.0         |
# |1              |0.6          |2025-01-01 00:29:35 |2025-01-01 00:36:02  |-7.2       |0.0       |-12.2       |0.0         |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
#
#
# =======================================================
#   BAD ROWS — Total amount < 0
#   Total: 63,037 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |1              |0.71         |2025-01-01 00:01:41 |2025-01-01 00:07:14  |-7.2       |3.66      |-8.54       |0.0         |
# |1              |0.69         |2025-01-01 00:55:54 |2025-01-01 01:00:38  |-6.5       |0.0       |-11.5       |0.0         |
# |1              |0.97         |2025-01-01 00:56:12 |2025-01-01 01:15:00  |-16.3      |0.0       |-21.3       |0.0         |
# |1              |1.42         |2025-01-01 00:55:53 |2025-01-01 01:06:49  |-12.1      |0.0       |-17.1       |0.0         |
# |1              |0.6          |2025-01-01 00:29:35 |2025-01-01 00:36:02  |-7.2       |0.0       |-12.2       |0.0         |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
#
#
# =======================================================
#   BAD ROWS — Tip amount < 0
#   Total: 124 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |1              |2.59         |2025-01-01 00:54:33 |2025-01-01 01:23:24  |-24.7      |-3.0      |-32.7       |0.0         |
# |1              |0.89         |2025-01-01 04:58:07 |2025-01-01 05:03:48  |-85.0      |-86.0     |-172.0      |0.0         |
# |1              |9.23         |2025-01-01 12:21:32 |2025-01-01 12:42:02  |-38.7      |-10.0     |-64.64      |-6.94       |
# |1              |0.0          |2025-01-01 21:33:27 |2025-01-01 21:33:49  |-3.0       |-11.0     |-19.0       |0.0         |
# |1              |18.44        |2025-01-02 00:38:24 |2025-01-02 01:03:13  |-68.1      |-14.62    |-89.47      |0.0         |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
#
#
# =======================================================
#   BAD ROWS — Tolls amount < 0
#   Total: 4,559 rows
# =======================================================
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |passenger_count|trip_distance|tpep_pickup_datetime|tpep_dropoff_datetime|fare_amount|tip_amount|total_amount|tolls_amount|
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+
# |4              |24.7         |2025-01-01 00:49:36 |2025-01-01 02:11:46  |-111.5     |0.0       |-123.44     |-6.94       |
# |1              |7.79         |2025-01-01 00:05:15 |2025-01-01 00:23:39  |-32.4      |0.0       |-48.59      |-6.94       |
# |2              |19.6         |2025-01-01 00:33:51 |2025-01-01 01:07:12  |-70.0      |0.0       |-80.19      |-6.94       |
# |1              |19.66        |2025-01-01 00:38:09 |2025-01-01 01:16:04  |-76.5      |0.0       |-88.44      |-6.94       |
# |4              |19.66        |2025-01-01 00:16:59 |2025-01-01 00:47:34  |-74.4      |0.0       |-86.34      |-6.94       |
# +---------------+-------------+--------------------+---------------------+-----------+----------+------------+------------+

# %% [markdown]
# ## Cleanup safety: remove empty/corrupted outbox folder before writing

# %%
if os.path.exists(OUTBOX) and not outbox_has_data(OUTBOX):
    print("OUTBOX exists but has no parquet parts. Deleting corrupted/empty outbox folder...")
    shutil.rmtree(OUTBOX)

# %% [markdown]
# ## ETL rules used in the final run
#
# This cell documents the business rules implemented in the final incremental Spark job.
#
# - **Cleaning rules**: keep only rows where required fields are non-null, `passenger_count > 0`, `trip_distance > 0`, `tpep_dropoff_datetime > tpep_pickup_datetime`, `fare_amount >= 0`, `total_amount >= 0`, `tip_amount >= 0`, and `tolls_amount >= 0`.
# - **Dedup key**: `VendorID`, `tpep_pickup_datetime`, `tpep_dropoff_datetime`, `PULocationID`, `DOLocationID`.
# - **Incremental behavior**: process only files not present in `state/manifest.json`.
# - **Idempotency**: anti-join new batch against existing outbox using the dedup key, then append only unseen records.

# %%
if not new_files:
    print("Nothing new to process. Exiting without changes.")
else:
    new_paths = [os.path.join(INBOX, f) for f in new_files]
    df_new = spark.read.parquet(*new_paths).withColumn("source_file", input_file_name())

    # ---------- Types ----------
    # Adjust types to expected schema for easier processing and consistency
    df_typed = (
        df_new
        .withColumn("tpep_pickup_datetime", col("tpep_pickup_datetime").cast("timestamp"))
        .withColumn("tpep_dropoff_datetime", col("tpep_dropoff_datetime").cast("timestamp"))
        .withColumn("passenger_count", col("passenger_count").cast("int"))
        .withColumn("trip_distance", col("trip_distance").cast("double"))
        .withColumn("PULocationID", col("PULocationID").cast("int"))
        .withColumn("DOLocationID", col("DOLocationID").cast("int"))
        .withColumn("VendorID", col("VendorID").cast("int"))
    )

    # ---------- Cleaning ----------
    # Cleaning possible wrong values: nulls, zero or negative counts/distances, dropoff before pickup, etc.
    df_clean = df_typed.filter(
        col("tpep_pickup_datetime").isNotNull()
        & col("tpep_dropoff_datetime").isNotNull()
        & col("passenger_count").isNotNull()
        & col("trip_distance").isNotNull()
        & col("PULocationID").isNotNull()
        & col("DOLocationID").isNotNull()
        & col("VendorID").isNotNull()
        & (col("passenger_count") > 0)
        & (col("trip_distance") > 0)
        & (col("tpep_dropoff_datetime") > col("tpep_pickup_datetime"))
        & (col("fare_amount") >= 0)
        & (col("total_amount") >= 0)
        & (col("tip_amount") >= 0)
        & (col("tolls_amount") >= 0)
    )

    # ---------- Dedup ----------
    # Create deduplication key based on fields that should uniquely identify a trip (except for source_file and ingested_at which are added later)
    dedup_key = ["VendorID", "tpep_pickup_datetime", "tpep_dropoff_datetime", "PULocationID", "DOLocationID"]

    # Remove duplicates within the current batch
    df_dedup = df_clean.dropDuplicates(dedup_key)

    # ---------- Enrichment ----------
    # Look for pickup and dropoff zones by joining with the lookup table on location IDs. Use broadcast join for small lookup table for better performance.
    zones = spark.read.parquet(LOOKUP)

    zones_pickup = zones.select(
        col("LocationID").alias("PULocationID"),
        col("Zone").alias("pickup_zone")
    )

    zones_dropoff = zones.select(
        col("LocationID").alias("DOLocationID"),
        col("Zone").alias("dropoff_zone")
    )

    # add pickup and dropoff zone names to the main dataframe by joining on location IDs. 
    # broadcast the lookup tables for better performance since they are small compared to the main trips data.
    df_enriched = (
        df_dedup
        .join(broadcast(zones_pickup), on="PULocationID", how="left")
        .join(broadcast(zones_dropoff), on="DOLocationID", how="left")
    )

    # ---------- Derived columns ----------
    # add some useful derived columns
    df_ready = (
        df_enriched
        .withColumn(
            "trip_duration_minutes",
            (unix_timestamp("tpep_dropoff_datetime") - unix_timestamp("tpep_pickup_datetime")) / 60.0
        )
        .withColumn("pickup_date", to_date("tpep_pickup_datetime"))
        .withColumn("ingested_at", current_timestamp())
    )

    # ---------- Select required output columns ----------
    df_out = df_ready.select(
        "VendorID",
        "tpep_pickup_datetime", "tpep_dropoff_datetime",
        "PULocationID", "DOLocationID",
        "pickup_zone", "dropoff_zone",
        "passenger_count", "trip_distance",
        "trip_duration_minutes", "pickup_date",
        "source_file", "ingested_at"
    ).dropDuplicates(dedup_key)

    # ---------- Metrics ----------
    input_rows = df_new.count()
    clean_rows = df_clean.count()
    dedup_rows = df_dedup.count()
    final_rows = df_out.count()

    print("Row counts (new batch):", {
        "input": input_rows,
        "after_cleaning": clean_rows,
        "after_dedup": dedup_rows,
        "final_output": final_rows
    })

    # ---------- Write ----------
    spark.conf.set("spark.sql.sources.partitionOverwriteMode", "dynamic")
    
    # ---------- Write ----------
    if final_rows > 0:
        if outbox_has_data(OUTBOX):
            df_existing = spark.read.parquet(OUTBOX)
            df_new_only = df_out.join(
                df_existing.select(dedup_key),
                on=dedup_key,
                how="left_anti"
            )
            
            df_final = df_existing.unionByName(df_new_only, allowMissingColumns=True)
            wrote = df_final.count()
            
            # Write "_tmp" then overwrite "OUTBOX" to avoid crashing
            OUTBOX_TMP = OUTBOX + "_tmp"
            df_final.coalesce(4).write.mode("overwrite").parquet(OUTBOX_TMP)
            shutil.rmtree(OUTBOX)
            shutil.move(OUTBOX_TMP, OUTBOX)
        else:
            wrote = final_rows
            df_out.coalesce(4).write.mode("overwrite").parquet(OUTBOX)
    else:
        wrote = 0
    print("Rows written:", wrote)
# Out:
# Row counts (new batch): {'input': 3475226, 'after_cleaning': 2816161, 'after_dedup': 2816157, 'final_output': 2816157}
# Rows written: 2816157

# %% [markdown]
# ## Manifest Update

# %%
for f in new_files:
    now = datetime.now(timezone.utc).isoformat()
    file_path = os.path.join(INBOX, f)
    manifest["processed_files"].append({
        "filename": f,
        "size_bytes": os.path.getsize(file_path),
        "row_count": input_rows,
        "processed_at": now
    })

save_manifest(STATE, manifest)

# %% [markdown]
# # Final Dataset

# %%
df_final = spark.read.parquet(OUTBOX)
df_final.show(5, truncate=False)
print(df_final.count())
# Out:
# +--------+--------------------+---------------------+------------+------------+-------------------------+--------------+---------------+-------------+---------------------+-----------+-------------------------------------------------------------------+--------------------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|PULocationID|DOLocationID|pickup_zone              |dropoff_zone  |passenger_count|trip_distance|trip_duration_minutes|pickup_date|source_file                                                        |ingested_at               |
# +--------+--------------------+---------------------+------------+------------+-------------------------+--------------+---------------+-------------+---------------------+-----------+-------------------------------------------------------------------+--------------------------+
# |2       |2025-01-01 03:38:57 |2025-01-01 04:05:11  |230         |1           |Times Sq/Theatre District|Newark Airport|4              |17.91        |26.233333333333334   |2025-01-01 |file:///home/jovyan/work/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-06 17:09:32.180535|
# |2       |2025-01-01 03:39:52 |2025-01-01 04:10:36  |170         |1           |Murray Hill              |Newark Airport|1              |17.33        |30.733333333333334   |2025-01-01 |file:///home/jovyan/work/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-06 17:09:32.180535|
# |2       |2025-01-01 07:28:57 |2025-01-01 07:47:16  |45          |1           |Chinatown                |Newark Airport|2              |12.09        |18.316666666666666   |2025-01-01 |file:///home/jovyan/work/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-06 17:09:32.180535|
# |2       |2025-01-01 07:43:59 |2025-01-01 08:10:26  |87          |1           |Financial District North |Newark Airport|1              |16.15        |26.45                |2025-01-01 |file:///home/jovyan/work/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-06 17:09:32.180535|
# |2       |2025-01-01 09:12:07 |2025-01-01 09:41:39  |162         |1           |Midtown East             |Newark Airport|3              |18.28        |29.533333333333335   |2025-01-01 |file:///home/jovyan/work/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-06 17:09:32.180535|
# +--------+--------------------+---------------------+------------+------------+-------------------------+--------------+---------------+-------------+---------------------+-----------+-------------------------------------------------------------------+--------------------------+
# only showing top 5 rows
#
# 2816157

# %% [markdown]
# ## Scenario

# %% [markdown]
# ### Identifying most frequent zone

# %%
df_scn = spark.read.parquet(OUTBOX)

zone_counts = df_scn.groupBy("pickup_zone").count()

total = df_scn.count()

top1 = (
    zone_counts
    .orderBy(desc("count"))
    .first()
)

hot_zone = top1["pickup_zone"]
hot_count = top1["count"]

print("Hot zone:", hot_zone)
print("Hot zone count:", hot_count)
print("Hot zone %:", round(100 * hot_count / total, 2), "%")
# Out:
# Hot zone: Upper East Side South
# Hot zone count: 148020
# Hot zone %: 5.26 %

# %% [markdown]
# ### Identifying top 10 Skew

# %%
top10 = (
    df_scn
    .groupBy("pickup_zone")
    .count()
    .withColumn("percentage", Fround(100 * col("count") / total, 2))
    .orderBy(desc("count"))
    .limit(10)
)

top10.show(truncate=False)
# Out:
# +----------------------------+------+----------+
# |pickup_zone                 |count |percentage|
# +----------------------------+------+----------+
# |Upper East Side South       |148020|5.26      |
# |Midtown Center              |146768|5.21      |
# |Upper East Side North       |137831|4.89      |
# |JFK Airport                 |133750|4.75      |
# |Penn Station/Madison Sq West|108184|3.84      |
# |Times Sq/Theatre District   |107545|3.82      |
# |Midtown East                |105066|3.73      |
# |Lincoln Square East         |97566 |3.46      |
# |LaGuardia Airport           |85435 |3.03      |
# |Midtown North               |84660 |3.01      |
# +----------------------------+------+----------+

# %% [markdown]
# ## Baseline

# %%
# This triggers a shuffle (Exchange) because groupBy is a wide transformation.
# Use Spark UI to capture baseline metrics (duration, shuffle write/read, spill).
baseline_agg = df_scn.groupBy("pickup_zone").count()

# %%
baseline_agg.orderBy(desc("count")).show(10, truncate=False)
# Out:
# +----------------------------+------+
# |pickup_zone                 |count |
# +----------------------------+------+
# |Upper East Side South       |148020|
# |Midtown Center              |146768|
# |Upper East Side North       |137831|
# |JFK Airport                 |133750|
# |Penn Station/Madison Sq West|108184|
# |Times Sq/Theatre District   |107545|
# |Midtown East                |105066|
# |Lincoln Square East         |97566 |
# |LaGuardia Airport           |85435 |
# |Midtown North               |84660 |
# +----------------------------+------+
# only showing top 10 rows

# %% [markdown]
# ## Without Most Popular Zone

# %%
# This checks whether removing the most frequent key changes runtime / shuffle behavior.
df_no_hot = df_scn.filter(col("pickup_zone") != hot_zone)

no_hot_agg = df_no_hot.groupBy("pickup_zone").count()

no_hot_agg.orderBy(desc("count")).show(10, truncate=False)
# Out:
# +----------------------------+------+
# |pickup_zone                 |count |
# +----------------------------+------+
# |Midtown Center              |146768|
# |Upper East Side North       |137831|
# |JFK Airport                 |133750|
# |Penn Station/Madison Sq West|108184|
# |Times Sq/Theatre District   |107545|
# |Midtown East                |105066|
# |Lincoln Square East         |97566 |
# |LaGuardia Airport           |85435 |
# |Midtown North               |84660 |
# |Upper West Side South       |81832 |
# +----------------------------+------+
# only showing top 10 rows

# %% [markdown]
# ## Repartition

# %%
# repartition forces an extra shuffle.
# It can help in severe skew cases (very dominant keys) by improving distribution,
# but it may add overhead when skew is mild.
repart_agg = (
    df_scn
    .repartition("pickup_zone")      # Extra shuffle to redistribute rows by key
    .groupBy("pickup_zone")
    .count()
)

repart_agg.orderBy(desc("count")).show(10, truncate=False)
# Out:
# +----------------------------+------+
# |pickup_zone                 |count |
# +----------------------------+------+
# |Upper East Side South       |148020|
# |Midtown Center              |146768|
# |Upper East Side North       |137831|
# |JFK Airport                 |133750|
# |Penn Station/Madison Sq West|108184|
# |Times Sq/Theatre District   |107545|
# |Midtown East                |105066|
# |Lincoln Square East         |97566 |
# |LaGuardia Airport           |85435 |
# |Midtown North               |84660 |
# +----------------------------+------+
# only showing top 10 rows
